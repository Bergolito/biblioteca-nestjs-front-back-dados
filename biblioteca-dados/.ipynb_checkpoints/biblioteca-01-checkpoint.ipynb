# %%
import pandas as pd

# %%
df = pd.read_csv('biblioteca.csv')

# %%
df
# Out:
#      Unnamed: 0  #ID                              TITULO  \
# 0           NaN    1                           Churchill
# 1           NaN    3            O Homem que sabia demais
# 2           NaN    4     Mein Kampf: A História do Livro
# 3           NaN    5                  Inovadores em Ação
# 4           NaN    7                       Code Breakers
# ..          ...  ...                                 ...
# 401         NaN  496  Comandos e Estratégias Espirituais
# 402         NaN  497                                 NaN
# 403         NaN  498                                 NaN
# 404         NaN  499                                 NaN
# 405         NaN  500                                 NaN
#
#                                              SUBTITULO  \
# 0                   Visionário. Estadista. Historiador
# 1               Alan Turing e a Invenção do Computador
# 2                                                  NaN
# 3    As estratégias das empresas que estão redefini...
# 4                    The inside story of Bletchey Park
# ..                                                 ...
# 401                       Entendendo a Unção Profética
# 402                                                NaN
# 403                                                NaN
# 404                                                NaN
# 405                                                NaN
#
#                                  AUTOR             EDITORA EDICAO     ANO  \
# 0                          John Lukacs  Jorge Zahar Editor      1  2002.0
# 1                        David Leavitt       Novo Conceito      1  2007.0
# 2                      Antoine Vitkine      Nova Fronteira      1  2010.0
# 3    William C. Taylor e Polly LaBarre            Sextante      1  2008.0
# 4          F. H. Hinsley & Alan Stripp              Oxford      1  1993.0
# ..                                 ...                 ...    ...     ...
# 401                   Jason Diamantino   Alethos Editorial      1  2025.0
# 402                                NaN                 NaN    NaN     NaN
# 403                                NaN                 NaN    NaN     NaN
# 404                                NaN                 NaN    NaN     NaN
# 405                                NaN                 NaN    NaN     NaN
#
#      N_PAGINAS LIDO IDIOMA  Unnamed: 11  Unnamed: 12
# 0        177.0    N    POR          NaN          1.0
# 1        221.0    N    POR          NaN          2.0
# 2        227.0    S    POR          NaN          3.0
# 3        266.0    S    POR          NaN          4.0
# 4        321.0    N    ING          NaN          5.0
# ..         ...  ...    ...          ...          ...
# 401      150.0    S    POR          NaN        410.0
# 402        NaN  NaN    NaN          NaN          NaN
# 403        NaN  NaN    NaN          NaN          NaN
# 404        NaN  NaN    NaN          NaN          NaN
# 405        NaN  NaN    NaN          NaN          NaN
#
# [406 rows x 13 columns]

# %%
df = pd.read_csv('biblioteca.csv')

autores = df['AUTOR'].unique()
cleaned_series = pd.Series(autores).dropna()
autores_list = cleaned_series.tolist()
autores_list
# Out:
# ['John Lukacs',
#  'David Leavitt',
#  'Antoine Vitkine',
#  'William C. Taylor e Polly LaBarre',
#  'F. H. Hinsley & Alan Stripp',
#  'Stuart Ball',
#  'Leander Kahney',
#  'Abel Basti',
#  'Stephen E. Ambrose',
#  'Rui Moreira Lima',
#  'Simon Singh',
#  'Sylvia Goulding',
#  'Jim Selman',
#  'William Douglas',
#  'Henrique Rattner',
#  'Luiz Eduardo Soares, André Batista, Rodrigo Pimentel',
#  'Luiz Eduardo Soares, Cláudio Ferraz, André Batista, Rodrigo Pimentel',
#  'Alfred J. Keller',
#  'Fábio Braga de Alencar',
#  'Grady Booch, James Rumbaugh, Ivar Jacobson',
#  'Andrew S. Tanenbaum',
#  'Alfred Lansing',
#  'Aguinaldo Aragon Fernandes, Vladimir Ferraz de Abreu',
#  'Fabrício Mariano',
#  'Aurélio Buarque de Holanda Ferreira',
#  'Jesús Hernández',
#  'Sun Tzu',
#  'Diana Preston',
#  'Robert Falcon Scott',
#  'Bryan Mark Rigg',
#  'Max Hueber Verlag',
#  'Paul Strathern',
#  'Adriano da Gama Cury',
#  'Ana Bremon',
#  'H. Rider Haggard',
#  'Robert Harris',
#  'T. Harv Eker',
#  'James C. Hunter',
#  'Mark Finley',
#  'Nilson da Silva',
#  'Nelson Piletti',
#  'Elmasri & Navathe',
#  'H. M. Deitel & P. J. Deitel',
#  'Roger S. Pressman',
#  'Silberschatz – Galvin – Gagne',
#  'J. Glenn Brookshear',
#  'Herbert Schildt',
#  'Bernardinho',
#  'Ricardo Soares & William Douglas',
#  'Kim Heldman',
#  'Douglas E. Comer',
#  'Nando Parrado, Vince Rause',
#  'Stephen King',
#  'Cláudio Bojunga',
#  'Luís Augusto Símon e Marcelo Prado',
#  'C. G. SWEETING ',
#  'TEC, NECHAMA',
#  'RASHKE, RICHARD',
#  'LAROUSSE EDITORIAL',
#  'ALBERTO DELLISOLA',
#  'Fernando Jorge',
#  'Padre Fábio de Melo',
#  'Graciliano Ramos',
#  'Olivier Ninge & Simonne Mortera',
#  'Ana Beatriz Barbosa Silva',
#  'Nilson Teixeira de Almeida',
#  'Carlos Saldanha Maranhão',
#  'Stormie Omartian',
#  'Antonio Mendez & Matt Baglio',
#  'Armando de Ramón',
#  'Ruth & Elmer Towns',
#  'Cristiano Arcoverde',
#  'Ellen G. White',
#  'Abe Huber',
#  'Kenneth E. Hagin',
#  'Charles Sheldon',
#  'Sheila Walsh',
#  'Nonna Bannister',
#  'Bernard W. Snelgrove',
#  'Dave Roberson',
#  'Kenneth E. Hagin e Kenneth Hagin Jr.',
#  'Alejandro Bullón',
#  'Walter Nather Jr.',
#  'Ricardo R. Lecheta',
#  'Mary Kay Ash',
#  'Carlos Ruiz Zafón',
#  'Nigel Cawthorne',
#  'Ignácio de Loyola Brandão',
#  'William P. Young',
#  'Lúcio Barreto Jr',
#  'Davi Lago e Lúcio Barreto Jr',
#  'Perilo Borba',
#  'Lúcio Barreto Jr & Davi Lago',
#  'Arilton Oliveira',
#  'Sandra Santos',
#  'Max Lucado',
#  'Loron Wade',
#  'Elvis Oliveira',
#  'Lúcio Barreto Jr & Richarde Guerra',
#  'Charles M. Sheldon',
#  'Eça de Queirós',
#  'Victoria Keller',
#  'Elias Freire',
#  'Alceu Luiz Pazzinato & Maria Helena Valente Senise',
#  'Richard Acklam with Sally Burgess',
#  'Billy Graham',
#  'Jesse Lyman Hurlbut',
#  'Benny Hinn',
#  'Sarah Young',
#  'Liao Yiwu',
#  'Miroslav Volf',
#  'Rice Broocks',
#  'Franklin Ferreira',
#  'Paulo Vieira',
#  'Anthony Burgess',
#  'Nilton Pereira da Cunha',
#  'Augusto Cury',
#  'Janio Cesar',
#  'Joyce Meyer',
#  'Frederico Pernambuco de Mello',
#  'Julie Orringer',
#  'Jimmy Swaggart',
#  'Tony Cooke',
#  'Fernandes Oliveira',
#  'Fernando Morais',
#  'Assuero Seixas',
#  'Josué Gonçalves',
#  'Jorge Linhares',
#  'Bud Wright',
#  'Jedida Ferro',
#  'Rick Renner',
#  'E. W. Kenyon',
#  'T. L. Osborn',
#  'Charles Capps',
#  'Mark W. Baker',
#  'Silas Malafaia',
#  'Walter Nather Jr',
#  'Sherry Argov',
#  'Laurentino Gomes',
#  'Eduardo Bueno',
#  'Daniel Souza',
#  'Kenneth W. Hagin',
#  'Simon Potter',
#  'Mark hankins',
#  'Myrna Grant',
#  'C.S. Lewis',
#  'Nancy Dufresne',
#  'Rick Warren',
#  'Mark Hankins',
#  'Elizabeth George',
#  'Dag Tessore',
#  'David Emigh',
#  'Luís Gonçalves/Diogo Cavalcanti',
#  'Abraão de Almeida',
#  'Alexandre Lopes',
#  'Dr. Ismael Sobrinho',
#  'Tim LaHaye',
#  'Luciano & Kelly Subirá',
#  'David Murray',
#  'Irmão Yun com Paul Hattaway',
#  'Shona & David Murray',
#  'Corrie Ten Boom com Elizabeth e John Sherril',
#  'Kenneth Hagin Jr',
#  'Godofredo Couto',
#  'André Martins',
#  'Alex Moriá',
#  'Dong Yu Lan',
#  'Pedro Dong',
#  'Mosab Hassan Yousef',
#  'Dra. Caroline Leaf',
#  'Hernandes Dias Lopes',
#  'Jason Diamantino']

# %%
#unique_names = df['Name'].unique()
headers=['NOME']
df = pd.DataFrame(autores_list, columns=headers)
df.to_csv('csv/autores-02.csv')

# %%
df = pd.read_csv('biblioteca.csv')
editoras = df['EDITORA'].unique()
editoras
# Out:
# array(['Jorge Zahar Editor', 'Novo Conceito', 'Nova Fronteira',
#        'Sextante', 'Oxford', 'Agir', nan, 'Bertrand Brasil', 'Incaer',
#        'Record', 'PubliFolha', 'Lonely planet', 'Pearson Prentice Hall',
#        'Campus Concursos', 'Nobel', 'Objetiva', 'Ciranda Cultural',
#        'Melhoramentos', 'Campus', 'Brasport', 'Madras', 'Editora 34',
#        'Alegro', 'Imago', 'Abril', 'Hueber', 'JORGE ZAHAR EDITOR', 'FTD',
#        'Cambridge University Press', 'Penguin Popular Classics',
#        'Ballantine Books', 'Casa Publicadora Brasileira', 'RiMa', 'Ática',
#        'Bestbolso', 'Wizard Brasil Franchising', 'Hal-Leonard', 'LTC',
#        'Bookman', 'McGrawHill', 'Makron Books', 'Abril Coleções',
#        'Ponto de Leitura', 'Leitura', 'JARDIM DOS LIVROS', 'RECORD',
#        '8INVERSO', 'LAROUSSE DO BRASIL', 'UNIVERSO DOS LIVROS',
#        'Geração Editorial', 'Planeta do Brasil', 'Editora Vozes',
#        'Fontanar', 'Saraiva', 'Mundo Cristão', 'Intríseca', 'Catalonia',
#        'Central Gospel', 'Galas Ediciones',
#        'Comunicação eficaz produções', 'Sociedade Bíblica do Brasil',
#        'Graça Editora', 'Thomas Nelson Brasil', 'Novo Século',
#        'Editora Verdade Viva', 'Ministério Verdade Viva', 'Willem Books',
#        'Novatec', 'Editora Kactus', 'CLA Editora', 'Suma de Letras',
#        'Gente Editora', 'Arqueiro', 'Editora Basileia ',
#        'Editora Central Gospel', 'Editora Basileia', 'Livro Rápido',
#        'Premius Editora', 'Editora Escala', 'Belotur', 'Editora Abril',
#        'Sociedade Bíblica Brasileira', 'IBEP', 'Longman', 'MC',
#        'Vida Acadêmica', 'Fiel Editora', 'Editora Aleph',
#        'Editora Universidade UFPE', 'Orvalho.com', 'Bello  Publicações',
#        'Graça Editorial', 'Adhonep', 'Massangana', 'Companhia das Letras',
#        'JCS Editora', 'Ministério Jimmy Swaggart', 'Rhema Brasil',
#        'Babecco', 'Julián Melgosa e Michelson Borges',
#        'Coleção Legado Bud Wright', 'Willën books', 'Getsêmani',
#        'Disney Pixar', 'CCS Gráfica e Editora', 'Coleção EI',
#        'Rhema Brasil Publicações', 'Wizard', 'Mensagem para Todos',
#        'Ediouro', 'Rhema Brasil publicações', 'Frutos do Espírito',
#        'Editora Betânia', 'Editora Vida', 'Academia', 'United Press',
#        'Paulinas', 'Culturama', 'bvbooks', 'Luz e Vida',
#        'Lynne Hammond/Patsy Cameneti', 'Otávio Lino/Marcio Sanches',
#        'Geográfica Editora',
#        'Cristiano Arcoverde Comunicações e Treinamentos', 'Vida',
#        'Bello Publicações', 'Editoria Betânia',
#        'Cristiano Arcoverde Comunicação e Treinamentos',
#        'Editora Árvore da Vida', 'Chara', 'Hagnos', 'Alethos Editorial'],
#       dtype=object)

# %%
headers=['NOME']
df = pd.DataFrame(editoras, columns=headers)
df.to_csv('csv/editoras-01.csv')

# %%
df = pd.read_csv('biblioteca.csv')
idiomas = df['IDIOMA'].unique()
idiomas
# Out:
# array(['POR', 'ING', 'ESP', 'ING/HOL', 'POR/ESP', 'POR/ALE',
#        'POR/ESP_ING', 'ING/POR', 'POR/ING', nan], dtype=object)

# %%
headers=['NOME']
df = pd.DataFrame(idiomas, columns=headers)
df.to_csv('csv/idiomas-01.csv')

# %%
# =================================
def salvar_csv_autores(df):
    # limpar valores nan
    autores = df['AUTOR'].unique()
    cleaned_series = pd.Series(autores).dropna()
    autores_list = cleaned_series.tolist()
    autores_list    
    
    # salvar
    headers=['NOME']
    df = pd.DataFrame(autores_list, columns=headers)
    arquivo='csv/autores-01.csv'
    print(f'Salvando o arquivo {arquivo}')
    df.to_csv(arquivo)    
# =================================    
def salvar_csv_editoras(df):
    # limpar valores nan
    editoras = df['EDITORA'].unique()
    cleaned_series = pd.Series(editoras).dropna()
    editoras_list = cleaned_series.tolist()
    editoras_list    
    
    # salvar
    headers=['NOME']
    df = pd.DataFrame(autores_list, columns=headers)
    arquivo='csv/editoras-01.csv'
    print(f'Salvando o arquivo {arquivo}')
    df.to_csv(arquivo)        
# =================================    
def salvar_csv_idiomas(df):
    # limpar valores nan
    idiomas = df['IDIOMA'].unique()
    cleaned_series = pd.Series(idiomas).dropna()
    idiomas_list = cleaned_series.tolist()
    idiomas_list   
    
    # salvar
    headers=['NOME']
    df = pd.DataFrame(idiomas_list, columns=headers)
    arquivo='csv/idiomas-01.csv'
    print(f'Salvando o arquivo {arquivo}')
    df.to_csv(arquivo)   
# =================================

# %%
df = pd.read_csv('biblioteca.csv')
salvar_csv_autores(df)
salvar_csv_editoras(df)
salvar_csv_idiomas(df)
# Out:
# Salvando o arquivo csv/autores-01.csv
# Salvando o arquivo csv/editoras-01.csv
# Salvando o arquivo csv/idiomas-01.csv
